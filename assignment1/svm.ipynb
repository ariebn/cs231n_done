# do the gradient check once again with regularization turned on
# you didn't forget the regularization gradient did you?
loss, grad = svm_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad)
# Out:
# numerical: 1.881414 analytic: 1.826770, relative error: 1.473585e-02
# numerical: -10.061213 analytic: -10.061213, relative error: 7.985315e-12
# numerical: -17.812151 analytic: -17.812151, relative error: 9.631159e-12
# numerical: 7.340518 analytic: 7.441601, relative error: 6.838215e-03
# numerical: 19.580935 analytic: 19.580935, relative error: 1.116030e-11
# numerical: -22.671901 analytic: -22.671901, relative error: 1.407365e-11
# numerical: -7.595875 analytic: -7.595875, relative error: 7.275904e-11
# numerical: 29.035396 analytic: 29.117936, relative error: 1.419346e-03
# numerical: 42.667113 analytic: 42.599697, relative error: 7.906498e-04
# numerical: -35.331665 analytic: -35.331665, relative error: 8.323697e-12
# now with regularization
# numerical: -9.355330 analytic: -9.286613, relative error: 3.686136e-03
# numerical: 2.122173 analytic: 2.122173, relative error: 4.759131e-11
# numerical: 3.997123 analytic: 3.997123, relative error: 2.838439e-11
# numerical: 9.505942 analytic: 9.505942, relative error: 3.514764e-11
# numerical: -16.847442 analytic: -16.847442, relative error: 2.765981e-11
# numerical: 4.785975 analytic: 4.785975, relative error: 4.491949e-11
# numerical: -5.390076 analytic: -5.390076, relative error: 3.462660e-11
# numerical: 15.259032 analytic: 15.259032, relative error: 4.686329e-11
# numerical: -6.622098 analytic: -6.622098, relative error: 3.275126e-11
# numerical: 20.668681 analytic: 20.668681, relative error: 9.887384e-12

# %% [markdown]
# ### Inline Question 1:
# It is possible that once in a while a dimension in the gradcheck will not match exactly. What could such a discrepancy be caused by? Is it a reason for concern? What is a simple example in one dimension where a gradient check could fail? *Hint: the SVM loss function is not strictly speaking differentiable*
#
# **Your Answer:** This would be if the dradient calculation falls at a point where the loss function is not differentiable . Then the abnalytic derivative would not match exactly the numeric derivative. In on dimension , consider:  y = { 0 if x<1; x if x>=1}. When x=1, the funtion is not differtiable. the derivative on the left is 0, on the right is 1. A numeric calculation would give any value between 0 and 1, depending on the analysis point.

# %%
# Next implement the function svm_loss_vectorized; for now only compute the loss;
# we will implement the gradient in a moment.
tic = time.time()
loss_naive, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.linear_svm import svm_loss_vectorized
tic = time.time()
loss_vectorized, _ = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# The losses should match but your vectorized implementation should be much faster.
print('difference: %f' % (loss_naive - loss_vectorized))
# Out:
# Naive loss: 8.899419e+00 computed in 0.061046s
# Vectorized loss: 8.899419e+00 computed in 0.004727s
# difference: 0.000000

# %%
# Complete the implementation of svm_loss_vectorized, and compute the gradient
# of the loss function in a vectorized way.

# The naive implementation and the vectorized implementation should match, but
# the vectorized version should still be much faster.
tic = time.time()
_, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss and gradient: computed in %fs' % (toc - tic))

tic = time.time()
_, grad_vectorized = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss and gradient: computed in %fs' % (toc - tic))

# The loss is a single number, so it is easy to compare the values computed
# by the two implementations. The gradient on the other hand is a matrix, so
# we use the Frobenius norm to compare them.
difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('difference: %f' % difference)

#print ('sums',np.sum(grad_naive), np.sum(grad_vectorized))
# Out:
# Naive loss and gradient: computed in 0.056576s
# bdls (500, 10)
# Vectorized loss and gradient: computed in 0.009610s
# difference: 0.000000

# %% [markdown]
# ### Stochastic Gradient Descent
#
# We now have vectorized and efficient expressions for the loss, the gradient and our gradient matches the numerical gradient. We are therefore ready to do SGD to minimize the loss.

# %%
# In the file linear_classifier.py, implement SGD in the function
# LinearClassifier.train() and then run it with the code below.
from cs231n.classifiers import LinearSVM
svm = LinearSVM()
tic = time.time()
loss_hist = svm.train(X_train, y_train, learning_rate=1e-7, reg=2.5e4,
                      num_iters=1500, batch_size = 200,verbose=True)
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 793.821438
# iteration 100 / 1500: loss 289.194490
# iteration 200 / 1500: loss 109.088199
# iteration 300 / 1500: loss 43.146318
# iteration 400 / 1500: loss 18.715851
# iteration 500 / 1500: loss 10.335086
# iteration 600 / 1500: loss 7.059015
# iteration 700 / 1500: loss 5.698083
# iteration 800 / 1500: loss 5.964858
# iteration 900 / 1500: loss 4.914116
# iteration 1000 / 1500: loss 5.658364
# iteration 1100 / 1500: loss 5.156064
# iteration 1200 / 1500: loss 4.871160
# iteration 1300 / 1500: loss 4.968058
# iteration 1400 / 1500: loss 5.149878
# That took 4.689616s

# %%
# A useful debugging strategy is to plot the loss as a function of
# iteration number:
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# Write the LinearSVM.predict function and evaluate the performance on both the
# training and validation set
y_train_pred = svm.predict(X_train)
print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
y_val_pred = svm.predict(X_val)
print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
# Out:
# training accuracy: 0.362000
# validation accuracy: 0.369000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of about 0.4 on the validation set.
learning_rates = [ 5e-8, 1e-7, 2.5e-7, 5e-7, 1e-6 ]
regularization_strengths = [5e4, 3.5e4, 2.5e4,1.5e4, 1e4, 5e3, 1e3]

# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
best_svm = None # The LinearSVM object that achieved the highest validation rate.

################################################################################
# TODO:                                                                        #
# Write code that chooses the best hyperparameters by tuning on the validation #
# set. For each combination of hyperparameters, train a linear SVM on the      #
# training set, compute its accuracy on the training and validation sets, and  #
# store these numbers in the results dictionary. In addition, store the best   #
# validation accuracy in best_val and the LinearSVM object that achieves this  #
# accuracy in best_svm.                                                        #
#                                                                              #
# Hint: You should use a small value for num_iters as you develop your         #
# validation code so that the SVMs don't take much time to train; once you are #
# confident that your validation code works, you should rerun the validation   #
# code with a larger value for num_iters.                                      #
################################################################################
for lr in learning_rates:
    for rs in regularization_strengths:
        svm = LinearSVM() 
        loss_hist = svm.train(X_train, y_train, learning_rate=lr, reg=rs,
                      num_iters=5000, batch_size = 200,verbose=False)
        y_train_pred = svm.predict(X_train)
        y_val_pred = svm.predict(X_val)
        train_acc = np.mean(y_train == y_train_pred)
        val_acc = np.mean(y_val == y_val_pred)
        results[(lr, rs)] = (train_acc, val_acc)
        print ('train, val accuracy=', train_acc, val_acc)
        if (val_acc > best_val):
            best_val = val_acc
            best_svm = svm
            best_lr = lr
            best_rs = rs
#print (results)               
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
print ('best hyper params lr,rs',best_lr, best_rs)
# Out:
# train, val accuracy= 0.35793877551 0.37
# train, val accuracy= 0.364163265306 0.378
# train, val accuracy= 0.372224489796 0.376
# train, val accuracy= 0.380367346939 0.379
# train, val accuracy= 0.385551020408 0.392
# train, val accuracy= 0.396020408163 0.388
# train, val accuracy= 0.35293877551 0.363
# train, val accuracy= 0.358510204082 0.365
# train, val accuracy= 0.365142857143 0.382
# train, val accuracy= 0.369469387755 0.375
# train, val accuracy= 0.383183673469 0.393
# train, val accuracy= 0.388142857143 0.403
# train, val accuracy= 0.396489795918 0.379
# train, val accuracy= 0.387040816327 0.366
# train, val accuracy= 0.339204081633 0.352
# train, val accuracy= 0.355408163265 0.364
# train, val accuracy= 0.332265306122 0.319
# train, val accuracy= 0.363918367347 0.367
# train, val accuracy= 0.378632653061 0.393
# train, val accuracy= 0.378612244898 0.367
# train, val accuracy= 0.403346938776 0.385
# train, val accuracy= 0.306959183673 0.336
# train, val accuracy= 0.319448979592 0.332
# train, val accuracy= 0.33093877551 0.335
# train, val accuracy= 0.35512244898 0.357
# train, val accuracy= 0.356795918367 0.36
# train, val accuracy= 0.367775510204 0.382
# train, val accuracy= 0.402714285714 0.388
# train, val accuracy= 0.270448979592 0.277
# train, val accuracy= 0.277020408163 0.257
# train, val accuracy= 0.292591836735 0.278
# train, val accuracy= 0.305224489796 0.324
# train, val accuracy= 0.328510204082 0.354
# train, val accuracy= 0.286653061224 0.283
# train, val accuracy= 0.351755102041 0.359
# lr 5.000000e-08 reg 1.000000e+03 train accuracy: 0.352939 val accuracy: 0.363000
# lr 5.000000e-08 reg 5.000000e+03 train accuracy: 0.396020 val accuracy: 0.388000
# lr 5.000000e-08 reg 1.000000e+04 train accuracy: 0.385551 val accuracy: 0.392000
# lr 5.000000e-08 reg 1.500000e+04 train accuracy: 0.380367 val accuracy: 0.379000
# lr 5.000000e-08 reg 2.500000e+04 train accuracy: 0.372224 val accuracy: 0.376000
# lr 5.000000e-08 reg 3.500000e+04 train accuracy: 0.364163 val accuracy: 0.378000
# lr 5.000000e-08 reg 5.000000e+04 train accuracy: 0.357939 val accuracy: 0.370000
# lr 1.000000e-07 reg 1.000000e+03 train accuracy: 0.387041 val accuracy: 0.366000
# lr 1.000000e-07 reg 5.000000e+03 train accuracy: 0.396490 val accuracy: 0.379000
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.388143 val accuracy: 0.403000
# lr 1.000000e-07 reg 1.500000e+04 train accuracy: 0.383184 val accuracy: 0.393000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.369469 val accuracy: 0.375000
# lr 1.000000e-07 reg 3.500000e+04 train accuracy: 0.365143 val accuracy: 0.382000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.358510 val accuracy: 0.365000
# lr 2.500000e-07 reg 1.000000e+03 train accuracy: 0.403347 val accuracy: 0.385000
# lr 2.500000e-07 reg 5.000000e+03 train accuracy: 0.378612 val accuracy: 0.367000
# lr 2.500000e-07 reg 1.000000e+04 train accuracy: 0.378633 val accuracy: 0.393000
# lr 2.500000e-07 reg 1.500000e+04 train accuracy: 0.363918 val accuracy: 0.367000
# lr 2.500000e-07 reg 2.500000e+04 train accuracy: 0.332265 val accuracy: 0.319000
# lr 2.500000e-07 reg 3.500000e+04 train accuracy: 0.355408 val accuracy: 0.364000
# lr 2.500000e-07 reg 5.000000e+04 train accuracy: 0.339204 val accuracy: 0.352000
# lr 5.000000e-07 reg 1.000000e+03 train accuracy: 0.402714 val accuracy: 0.388000
# lr 5.000000e-07 reg 5.000000e+03 train accuracy: 0.367776 val accuracy: 0.382000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.356796 val accuracy: 0.360000
# lr 5.000000e-07 reg 1.500000e+04 train accuracy: 0.355122 val accuracy: 0.357000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.330939 val accuracy: 0.335000
# lr 5.000000e-07 reg 3.500000e+04 train accuracy: 0.319449 val accuracy: 0.332000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.306959 val accuracy: 0.336000
# lr 1.000000e-06 reg 1.000000e+03 train accuracy: 0.351755 val accuracy: 0.359000
# lr 1.000000e-06 reg 5.000000e+03 train accuracy: 0.286653 val accuracy: 0.283000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.328510 val accuracy: 0.354000
# lr 1.000000e-06 reg 1.500000e+04 train accuracy: 0.305224 val accuracy: 0.324000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.292592 val accuracy: 0.278000
# lr 1.000000e-06 reg 3.500000e+04 train accuracy: 0.277020 val accuracy: 0.257000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.270449 val accuracy: 0.277000
# best validation accuracy achieved during cross-validation: 0.403000
# best hyper params lr,rs 1e-07 10000.0

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

 
# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(3, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(3, 1, 3)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Evaluate the best svm on test set
y_test_pred = best_svm.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('linear SVM on raw pixels final test set accuracy: %f' % test_accuracy)
# Out:
# linear SVM on raw pixels final test set accuracy: 0.388000

# %%
# Visualize the learned weights for each class.
# Depending on your choice of learning rate and regularization strength, these may
# or may not be nice to look at.
w = best_svm.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)
w_min, w_max = np.min(w), np.max(w)
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
      
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %% [markdown]
# ### Inline question 2:
# Describe what your visualized SVM weights look like, and offer a brief explanation for why they look they way that they do.
#
# *** They look similar to a "commom" feature/color of each class e.g. Deer has a green background
